# %% [markdown]
# <a href="https://colab.research.google.com/github/msskx/deep_study/blob/main/01_the_machine_learning_landscape.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#第四个案例调整坐标轴
import matplotlib.pyplot as plt
import numpy as np

x=np.linspace(-3,3,50)
y1=2*x+1
y2=x**2
#在每个figure中显示图形，num给每个figure编号

plt.figure(num=3,figsize=(8,5))#设置figure的长为8宽为5
plt.plot(x,y1)
plt.plot(x,y2,color='red',linewidth=1.0,linestyle='--')#设置颜色，线的宽度，线的表现形式

plt.xlim(-1,2,5)
plt.ylim(-1,2,5)

plt.xlabel('I am X')
plt.ylabel('I am Y')

new_ticks=np.linspace(-1,2,5)
plt.xticks(new_ticks)
plt.yticks([-2,-1.8,-1,1.22,3],[r'$really\ bad$',r'$bad$',r'normal',r'$good$',r'$really\ good$'])

#gca get current axis获取当前框架

ax=plt.gca()

ax.spines['right'].set_color('none')#将右边框透明化
ax.spines['top'].set_color('none')

ax.xaxis.set_ticks_position('bottom')#用下面的坐标轴替换xaxis
ax.yaxis.set_ticks_position('left')
#挪动

ax.spines['bottom'].set_position(('data',0))
ax.spines['left'].set_position(('data',0))
plt.show()
